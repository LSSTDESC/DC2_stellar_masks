# %%
import sys
sys.path.append('../bright_objects_masks')
import radius_study
import call_dc2
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append('../bright_objects_masks')
# ----> 3 import radius_study
#       4 import call_dc2
#       5 import warnings
#
# File ~/workspace/side_codes/clusters/DC2/DC2_mask/bright_objects_masks/desc_package/Examples/../bright_objects_masks/radius_study.py:10
#       8 import call_dc2
#       9 sys.path.append('_multiprocessing')
# ---> 10 from _multiprocessing import s_multiprocessing# import _Multiprocessing
#      11 ### This one is highly recommended to be parallelized
#      12 class Calculate_density:
#
# ModuleNotFoundError: No module named 's_multiprocessing'

# %%
sys.path.append('../bright_objects_masks')

# %%
import call_dc2

# %%
from _mprocessing.s_multiprocessing import Multiprocessing

# %%
dir(_mprocessing.s_multiprocessing)
# Out:
# ['Multiprocessing',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'call_dc2',
#  'current_dir',
#  'np',
#  'os',
#  'subprocess',
#  'sys',
#  'time',
#  'yaml']

# %%
_mprocessing.__spec__
# Out:
# ModuleSpec(name='_mprocessing', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7f3104767f70>, origin='/pbs/home/n/namourou/workspace/side_codes/clusters/DC2/DC2_mask/bright_objects_masks/desc_package/Examples/../bright_objects_masks/_mprocessing/__init__.py', submodule_search_locations=['/pbs/home/n/namourou/workspace/side_codes/clusters/DC2/DC2_mask/bright_objects_masks/desc_package/Examples/../bright_objects_masks/_mprocessing'])

# %%
from _mprocessing import

# %%
sys.path.append('../../')

# %%
from bright_objects_masks._multiprocessing import s_multiprocessing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from bright_objects_masks._multiprocessing import s_multiprocessing
#
# ModuleNotFoundError: No module named 'bright_objects_masks'

# %%
import _mprocessing

# %%
dir(_mprocessing)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__']

# %%
_mprocessing.s_multiprocessing
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 _mprocessing.s_multiprocessing
#
# AttributeError: module '_mprocessing' has no attribute 's_multiprocessing'

# %% [markdown]
# In this notebook, we show how to compute the density ratio as a function of radius around stars.
# As a reminder, we have density_ratio(r) = density(r)/mean_catalog_density.

# %% [markdown]
# Basic way to compute density_ratio(r)

# %%
critical_radius = radius_study.Critical_radius(tract_list=[3830,4236])

# %% [markdown]
# There are several configuration parameters which allows one to do the calculation without having to open the catalog by hand.

# %%
critical_radius = radius_study.Critical_radius(name='dc2_object_run2.2i_dr6_v2_with_addons_v2', theta_bins = np.logspace(np.log10(0.5),np.log10(50), 50), 
        tract_list = None, quantities = ['ra','dec','mag_i_cModel'], conditions=None, conditions_galaxies=["extendedness==1", "mag_i_cModel>17", "mag_i_cModel<25.3"], 
        conditions_stars=["extendedness==0"], binned_quantity="mag_i_cModel", bins=[0, 17, 18, 20, 22, 24])

# %% [markdown]
# First, we read objects catalogs and apply selected cuts. This method returns galaxies, neighbouring tracts galaxies, stars.

# %%
density_glob = critical_radius.get_density_ratio()
# Out:
# [3830, 4236]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 density_glob = critical_radius._open_catalogs()
#
# File ~/workspace/side_codes/clusters/DC2/DC2_mask/bright_objects_masks/desc_package/Examples/../bright_objects_masks/radius_study.py:202, in Critical_radius._open_catalogs(self)
#     200 print(self.tract_list)
#     201 if len(self.tract_list)>1:
# --> 202     galaxies = smp._open_catalogs(self.name, 'galaxies', self.quantities, self.conditions, self.conditions_galaxies, self.tract_list)
#     203     galaxies_neighbour = m_func._multiprocessing(partial_neighbours, [3830,4236])
#     204     stars = m_func._multiprocessing(partial_stars, [3830,4236])
#
# ...

# %%
print(density_glob)

# %%
import numpy as np
theta_bins = np.logspace(np.log10(0.5),np.log10(50), 50)

# %% [markdown]
# If density_ratio is calculated, it can directly be given to get_critical_radius. Otherwize it will do the calculation by itself

# %%
critical_radius_value = critical_radius.get_critical_radius(density_ratio=density_glob, critical_density=0.9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 critical_radius_value = critical_radius.get_critical_radius(density_ratio=density_glob, critical_density=0.9)
#
# File ~/workspace/side_codes/clusters/DC2/DC2_mask/bright_objects_masks/desc_package/Examples/../bright_objects_masks/radius_study.py:247, in critical_radius.get_critical_radius(self, density_ratio, critical_density)
#     245     critical_radius_value = round(self.theta_bins[np.where(density_ratio>=critical_density)[0]],2)
#     246 else :
# --> 247     critical_radius_value = [round(self.theta_bins[np.where(density_ratio[i]>=critical_density)[0][0]],2) for i in range(len(self.bins)-1)]
#     248 return critical_radius_value
#
# File ~/workspace/side_codes/clusters/DC2/DC2_mask/bright_objects_masks/desc_package/Examples/../bright_objects_masks/radius_study.py:247, in <listcomp>(.0)
# ...

# %%
print(critical_radius)

# %%
import matplotlib.pyplot as plt
for i in range(len(density_glob)):
    plt.close()
    plt.plot(theta_bins, density_glob[i], label ='d(r,mag)')
    plt.axvline(critical_radius[i], color='red', linestyle = '--', label = f'r_lim={critical_radius[i]}"')
    plt.xlabel("radius [arcsec]")
    plt.ylabel("density_ratio")
    plt.legend()
    plt.show()
